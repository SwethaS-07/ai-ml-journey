# %% [markdown]
# <a href="https://colab.research.google.com/github/SwethaS-07/ai-ml-journey/blob/main/day03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arr = np.array([25,24,5,2])

# %%
print(arr+1)
# Out:
# [26 25  6  3]

# %%
print(arr-5)
# Out:
# [20 19  0 -3]

# %%
print(arr*5)
# Out:
# [125 120  25  10]

# %%
print(arr/5)
# Out:
# [5.  4.8 1.  0.4]

# %%
print(arr**5)
# Out:
# [9765625 7962624    3125      32]

# %%
#functions

# %%
brr = np.sqrt(arr)
print(brr)
# Out:
# [5.         4.89897949 2.23606798 1.41421356]

# %%
print(np.round(brr))
# Out:
# [5. 5. 2. 1.]

# %%
print(np.floor(brr))
# Out:
# [5. 4. 2. 1.]

# %%
print(np.ceil(brr))
# Out:
# [5. 5. 3. 2.]

# %%
# two arrays operations

# %%
arr = np.array([1,2,3,4])

# %%
brr = np.array([5,6,7,8])

# %%
print(arr+brr)
# Out:
# [ 6  8 10 12]

# %%
print(arr-brr)
# Out:
# [-4 -4 -4 -4]

# %%
print(arr*brr)
# Out:
# [ 5 12 21 32]

# %%
print(brr/arr)
# Out:
# [5.         3.         2.33333333 2.        ]

# %%
#constants

# %%
print(np.pi)
# Out:
# 3.141592653589793

# %%
#comparison operator

# %%
age = np.array([25,26,78,90,40,35])

# %%
print(age<18)
# Out:
# [False False False False False False]

# %%
print(age>18)
# Out:
# [ True  True  True  True  True  True]
